# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load dataset from our source

athletes = pd.read_csv('C:/Users/Surendran.Sakthivel/Downloads/Olympics Dataset/athlete_events.csv')
regions = pd.read_csv('C:/Users/Surendran.Sakthivel/Downloads/Olympics Dataset/noc_regions.csv')

# %%
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
#Combine both datasets and join dataframes using merge function

athletes_df = athletes.merge(regions, how = 'left', on = 'NOC')
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
#Count the rows and columns in dataset

athletes_df.shape
# Out:
# (271116, 17)

# %%
#column names consistent

athletes_df.rename(columns={'region':'Region', 'notes': 'Notes'}, inplace=True);
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       Region Notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
#info about the columns

athletes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
#info about the columns with statistics

athletes_df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#check null values

nan_values = athletes_df.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
athletes_df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
nan_values = df.isna()
nan_columns = nan_values.any()

columns_with_nan = df.columns[nan_columns].tolist()
print(columns_with_nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SUREND~1.SAK\AppData\Local\Temp/ipykernel_10820/536508942.py in <module>
# ----> 1 nan_values = df.isna()
#       2 nan_columns = nan_values.any()
#       3
#       4 columns_with_nan = df.columns[nan_columns].tolist()
#       5 print(columns_with_nan)
#
# NameError: name 'df' is not defined

# %%
athletes_list = athletes_df.columns[athletes_df.isnull().any()].tolist
athletes_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Age', 'Height', 'Weight', 'Medal', 'Region', 'Notes'], dtype='object')>

# %%
#Data for Specific Countries
#For India

athletes_df.query('Team == "India"').head(10)
# Out:
#        ID                             Name Sex   Age  Height  Weight   Team  \
# 505   281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 506   281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 895   512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896   512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897   512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 898   512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 899   512  Shiny Kurisingal Abraham-Wilson   F  27.0   167.0    53.0  India
# 900   512  Shiny Kurisingal Abraham-Wilson   F  31.0   167.0    53.0  India
# 1183  663            Sharath Kamal Achanta   M  22.0   186.0    85.0  India
# 1184  663            Sharath Kamal Achanta   M  26.0   186.0    85.0  India
#
#       NOC        Games  Year  Season         City         Sport  \
# 505   IND  1928 Summer  1928  Summer    Amsterdam     Athletics
# ...

# %%
athletes_df[athletes_df["Team"] == "India"]
# Out:
#             ID                                           Name Sex   Age  \
# 505        281                                 S. Abdul Hamid   M   NaN
# 506        281                                 S. Abdul Hamid   M   NaN
# 895        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 896        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 897        512                Shiny Kurisingal Abraham-Wilson   F  23.0
# ...        ...                                            ...  ..   ...
# 264139  132177                           Mohammad Anas Yahiya   M  21.0
# 265876  133029  Thyadathuvilla Chandrapillai "T. C." Yohannan   M  29.0
# 266934  133554                           Sayed Muhammad Yusuf   M   NaN
# 270912  135480                                   Geeta Zutshi   F  23.0
# 270913  135480                                   Geeta Zutshi   F  27.0
#
#         Height  Weight   Team  NOC        Games  Year  Season            City  \
# ...

# %%
athletes_df.query('Team == "India"')
# Out:
#             ID                                           Name Sex   Age  \
# 505        281                                 S. Abdul Hamid   M   NaN
# 506        281                                 S. Abdul Hamid   M   NaN
# 895        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 896        512                Shiny Kurisingal Abraham-Wilson   F  19.0
# 897        512                Shiny Kurisingal Abraham-Wilson   F  23.0
# ...        ...                                            ...  ..   ...
# 264139  132177                           Mohammad Anas Yahiya   M  21.0
# 265876  133029  Thyadathuvilla Chandrapillai "T. C." Yohannan   M  29.0
# 266934  133554                           Sayed Muhammad Yusuf   M   NaN
# 270912  135480                                   Geeta Zutshi   F  23.0
# 270913  135480                                   Geeta Zutshi   F  27.0
#
#         Height  Weight   Team  NOC        Games  Year  Season            City  \
# ...

# %%
athletes_df[(athletes_df["Team"] == "India") & (athletes_df["Sex"] == "M")].head(10)
# Out:
#         ID                         Name Sex   Age  Height  Weight   Team  NOC  \
# 505    281               S. Abdul Hamid   M   NaN     NaN     NaN  India  IND
# 506    281               S. Abdul Hamid   M   NaN     NaN     NaN  India  IND
# 1183   663        Sharath Kamal Achanta   M  22.0   186.0    85.0  India  IND
# 1184   663        Sharath Kamal Achanta   M  26.0   186.0    85.0  India  IND
# 1185   663        Sharath Kamal Achanta   M  34.0   186.0    85.0  India  IND
# 1710   952          Badathala Adisekhar   M  28.0     NaN    53.0  India  IND
# 1711   952          Badathala Adisekhar   M  32.0     NaN    53.0  India  IND
# 1998  1105              Mirza Najib Aga   M  19.0     NaN     NaN  India  IND
# 2383  1331                   Jahan Ahir   M   NaN     NaN     NaN  India  IND
# 2441  1366  Jitendarjit Singh Ahluwalia   M  25.0   179.0    69.0  India  IND
#
#             Games  Year  Season            City          Sport  \
# ...

# %%
athletes_df[(athletes_df["Team"] == "India") & (athletes_df["Sex"] == "F")].head(10)
# Out:
#         ID                             Name Sex   Age  Height  Weight   Team  \
# 895    512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896    512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897    512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 898    512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 899    512  Shiny Kurisingal Abraham-Wilson   F  27.0   167.0    53.0  India
# 900    512  Shiny Kurisingal Abraham-Wilson   F  31.0   167.0    53.0  India
# 2070  1149                    Neha Aggarwal   F  18.0   170.0    67.0  India
# 2595  1455                       Neha Ahuja   F  24.0   162.0    54.0  India
# 2596  1455                       Neha Ahuja   F  24.0   162.0    54.0  India
# 5387  3053                   Bobby Aloysius   F  30.0   173.0    55.0  India
#
#       NOC        Games  Year  Season         City          Sport  \
# ...

# %%
pivot_table = athletes_df.pivot_table(index="country", columns="type", values= "Region", aggfunc='count', fill_value=0).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SUREND~1.SAK\AppData\Local\Temp/ipykernel_10820/1194153321.py in <module>
# ----> 1 pivot_table = athletes_df.pivot_table(index="country", columns="type", values= "Region", aggfunc='count', fill_value=0).reset_index()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    7949         from pandas.core.reshape.pivot import pivot_table
#    7950
# -> 7951         return pivot_table(
#    7952             self,
#    7953             values=values,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
# ...

# %%
athletes_df.query('"Medal" == "Gold" , "Team" == "India")
# Out:
#   File "C:\Users\SUREND~1.SAK\AppData\Local\Temp/ipykernel_10820/2489280671.py", line 1
#     athletes_df.query('"Medal" == "Gold" , "Team" == "India")
#                                                              ^
# SyntaxError: EOL while scanning string literal

# %%
athletes_df[(athletes_df["Team"] == "India") & (athletes_df["Medal"] == "Gold")].head(10)
# Out:
#           ID                             Name Sex   Age  Height  Weight  \
# 4732    2699                      Shaukat Ali   M  30.0     NaN     NaN
# 4736    2703                 Syed Mushtaq Ali   M  22.0   165.0    61.0
# 5032    2864              Richard James Allen   M  25.0   172.0     NaN
# 5033    2864              Richard James Allen   M  30.0   172.0     NaN
# 5034    2864              Richard James Allen   M  34.0   172.0     NaN
# 10274   5618            Sardar Mohammad Aslam   M   NaN     NaN     NaN
# 21208  11197              Vasudevan Bhaskaran   M  29.0   174.0    68.0
# 22004  11601                   Abhinav Bindra   M  25.0   173.0    70.0
# 24657  12911              Lal Shah S. Bokhari   M  23.0   173.0     NaN
# 29022  15011  Frank Gerald Singlehurst Brewin   M  22.0     NaN     NaN
#
#         Team  NOC        Games  Year  Season         City     Sport  \
# 4732   India  IND  1928 Summer  1928  Summer    Amsterdam    Hockey
# ...

# %%
athletes_df[(athletes_df["Team"] == "India") & (athletes_df["Medal"] == "Silver")].head(10)
# Out:
#            ID                                Name Sex   Age  Height  Weight  \
# 8192     4518          Joseph Anthony "Joe" Antic   M  29.0   168.0    59.0
# 42476   21912              Leslie Walter Claudius   M  33.0   162.0    53.0
# 128928  64909                Sushil Kumar Solanki   M  29.0   166.0    66.0
# 128930  64910                         Vijay Kumar   M  26.0   170.0    70.0
# 131253  66061                        Mohinder Lal   M  24.0   165.0    58.0
# 133788  67372               Shankar Pillay Laxman   M  27.0   167.0    64.0
# 186589  93798           Victor John "V. J." Peter   M  23.0   165.0    59.0
# 193366  97066  Norman Gilbert Pritchard (-Trevor)   M  24.0     NaN     NaN
# 193368  97066  Norman Gilbert Pritchard (-Trevor)   M  24.0     NaN     NaN
# 197400  99103          Rajyavardhan Singh Rathore   M  34.0   188.0    85.0
#
#          Team  NOC        Games  Year  Season    City      Sport  \
# 8192    India  IND  1960 Summer  1960  Summer    Roma     Hockey
# ...

# %%
athletes_df[(athletes_df["Team"] == "India") & (athletes_df["Medal"] == "Bronze")].head(10)
# Out:
#            ID                          Name Sex   Age  Height  Weight   Team  \
# 21815   11520   Govinda Billimogaputtaswamy   M  20.0   171.0    60.0  India
# 41379   21339      Rajendra Absolem Christy   M  30.0   165.0    58.0  India
# 44817   23098             Charles Cornelius   M  26.0   170.0    65.0  India
# 60361   30913                Yogeshwar Dutt   M  29.0   168.0    65.0  India
# 72611   36928              Manuel Frederick   M  23.0   172.0    65.0  India
# 105302  53275    Khashaba Dadasaheb  Jahdav   M  25.0     NaN     NaN  India
# 119437  60461                 Michael Kindo   M  25.0   170.0    62.0  India
# 123303  62303  Mangte Chungneijang Mary Kom   F  29.0   158.0    51.0  India
# 128895  64886                   Ashok Kumar   M  22.0   170.0    57.0  India
# 128927  64909          Sushil Kumar Solanki   M  25.0   166.0    66.0  India
#
#         NOC        Games  Year  Season         City      Sport  \
# ...

# %%
top_15_countries = athletes_df.Team.value_counts().sort_values(ascending=False).head(15)
top_15_countries
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Poland            6143
# Switzerland       5844
# Netherlands       5718
# Soviet Union      5535
# Finland           5379
# Name: Team, dtype: int64

# %%
top_15_sports = athletes_df.Sport.value_counts().sort_values(ascending=False).head(15)
top_15_sports
# Out:
# Athletics               38624
# Gymnastics              26707
# Swimming                23195
# Shooting                11448
# Cycling                 10859
# Fencing                 10735
# Rowing                  10595
# Cross Country Skiing     9133
# Alpine Skiing            8829
# Wrestling                7154
# Football                 6745
# Sailing                  6586
# Equestrianism            6344
# Canoeing                 6171
# Boxing                   6047
# Name: Sport, dtype: int64

# %%
#plot for the top 15 Sports

plt.figure(figsize=(26,14))
#plt.xticks(rotation=20)
plt.title('Top participation from various sports')
sns.barplot(x=top_15_sports.index, y=top_15_sports, palette = 'Set1');

# %%
#Wrong code came from internet need work.

df = sns.load_dataset('tips')
sns.countplot(y ='sex', hue = "smoker", data = df)
plt.show()

# %%
#Random from internet

fig = plt.figure()
ax = plt.axes(projection ='3d')
z = np.linspace(0, 1, 1000)
x = z * np.sin(75 * z)
y = z * np.cos(75 * z)
ax.plot3D(x, y, z, 'purple')
ax.set_title('3D PLOT')
plt.show()

# %%
top_holders = athletes_df.Medal.value_counts().sort_values(ascending=False).head(15)
top_holders
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(12,6))
#plt.xticks(rotation=20)
plt.title('Top Holders')
sns.barplot(x=top_holders.index, y=top_holders, palette = 'Set2');

# %%
Holders = ['GOLD', 'SILVER', 'BRONZE','NA']
fig = plt.figure(figsize =(10, 7))
plt.pie(athletes_df.Year, labels = Holders)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SUREND~1.SAK\AppData\Local\Temp/ipykernel_10820/1191811597.py in <module>
#       1 Holders = ['GOLD', 'SILVER', 'BRONZE','NA']
#       2 fig = plt.figure(figsize =(10, 7))
# ----> 3 plt.pie(athletes_df.Year, labels = Holders)
#       4 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
plt.figure(figsize=(18,7))
plt.title("Age distribution")
plt.xlabel('Age')
plt.ylabel('Number of players')
plt.hist(athletes_df.Age, bins = np.arange(18,70,3), color='coral', edgecolor = 'White');

# %%
plt.figure(figsize=(18,7))
plt.title("Weight Chart")
plt.xlabel('Weight(Kgs)')
plt.ylabel('Number of players')
plt.hist(athletes_df.Weight, bins = np.arange(18,150,2), color='silver', edgecolor = 'purple');

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='Year', data=womenOlympics, palette="Spectral")
plt.title('Women Participation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SUREND~1.SAK\AppData\Local\Temp/ipykernel_10136/3417020438.py in <module>
# ----> 1 sns.set(style="darkgrid")
#       2 plt.figure(figsize=(20, 10))
#       3 sns.countplot(x='Year', data=womenOlympics, palette="Spectral")
#       4 plt.title('Women Participation')
#
# NameError: name 'sns' is not defined

# %%
goldMedals = goldMedals[np.isfinite(goldMedals['Age'])]

# %%
goldMedals['ID'][goldMedals['AGE'] > 60].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SUREND~1.SAK\AppData\Local\Temp/ipykernel_10136/1004431513.py in <module>
# ----> 1 goldMedals['ID'][goldMedals['AGE'] > 60].count()
#
# NameError: name 'goldMedals' is not defined
